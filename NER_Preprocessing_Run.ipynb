# %%
import os

# %%
os.chdir('/content/drive/MyDrive/Colab Notebooks/Digilytics/BERT_NER/NER-Preprocessing')

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/Colab Notebooks/Digilytics/BERT_NER/NER-Preprocessing/.git/

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Colab Notebooks/Digilytics/BERT_NER/NER-Preprocessing'

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 1.8MB 12.6MB/s
# ...
#      |████████████████████████████████| 2.9MB 35.0MB/s
# ...
#      |████████████████████████████████| 890kB 49.4MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=e593adf270330148bd599f13d057ef289b28f713e35cc3cad14242ec8ba28c5f
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...

# %%
# !pip install pytorch_pretrained_bert
# Out:
# ...
#      |████████████████████████████████| 133kB 14.6MB/s
# ...
#      |████████████████████████████████| 133kB 17.4MB/s
# ...
#      |████████████████████████████████| 71kB 4.8MB/s
# ...
#      |████████████████████████████████| 7.2MB 38.5MB/s
# ...
# ERROR: botocore 1.19.54 has requirement urllib3<1.27,>=1.25.4; python_version != "3.4", but you'll have urllib3 1.24.3 which is incompatible.
# ...

# %%
# !python main.py
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Preprocessing Complete....
# NER Started....
# 2021-01-14 09:27:30,614 INFO_NER: preprocessing data ...
# 2021-01-14 09:27:30,941 INFO_NER: Data has been preprocessed
# 2021-01-14 09:27:30,942 INFO_NER: Making checkpoint for the preprocessed data ...
# 2021-01-14 09:27:31,230 INFO_NER:  Splitting data and creating data sets ...
# 2021-01-14 09:27:31,232 INFO_NER: Moving model to cuda ...
# No GPU available, using the CPU instead.
# 2021-01-14 09:27:42,362 INFO_NER: Starting Fine-tuning ...
# 2021-01-14 09:27:42,362 INFO_NER: Start epoch 1
#   0% 0/163 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "main.py", line 38, in <module>
#     model.training()
#   File "/content/drive/My Drive/Colab Notebooks/Digilytics/BERT_NER/NER-Preprocessing/NER_model.py", line 167, in training
#     self.scheduler)
# ...

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/Colab Notebooks/Digilytics/BERT_NER/NER-Preprocessing/.git/

# %%
# !git add *
# Out:
# fatal: unable to stat 'models/finbert-uncased/pytorch_model.bin': No such file or directory

# %%
# !git commit -m ""
